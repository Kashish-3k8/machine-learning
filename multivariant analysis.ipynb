# %%
import pandas as pd

# %%
import matplotlib as plt
import seaborn as sns
df = pd.read_csv('train.csv')
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %% [markdown]
# scatter plot ( numerical numerical data)

# %%
df2 = pd.read_csv('tip.csv')
df2.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
sns.scatterplot(data = df2, x= 'total_bill', y= 'tip', hue = 'sex', style ='smoker', size = 'size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# 2. bar plot ( numerical - categorical)

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
sns.barplot(data = df, x = 'Pclass', y = 'Age')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(data = df, x = 'Pclass', y = 'Fare')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(data = df, x = 'Pclass', y = 'Fare', hue = 'Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(data = df, x = 'Pclass', y = 'Age', hue = 'Sex')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# 3. Box plot (numerical - categorical)

# %%
sns.boxplot(data = df, x= 'Pclass', y= 'Age')
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(data = df, x= 'Sex', y= 'Age', hue = 'Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# 4. Distplot(numerical - categorical)

# %%
sns.distplot(df[df['Survived'] == 0]['Age'],hist= False)
sns.distplot(df[df['Survived'] == 1]['Age'],hist= False)
# Out:
# C:\Users\BIT\AppData\Local\Temp\ipykernel_28792\81805454.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived'] == 0]['Age'],hist= False)
# C:\Users\BIT\AppData\Local\Temp\ipykernel_28792\81805454.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# ...

# %% [markdown]
# 5. Heatmap(categorical - categorical)

# %%
sns.heatmap(pd.crosstab(df['Pclass'], df['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
df.groupby('Sex')['Survived'].mean()*100
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %% [markdown]
# 6. ClusterMap (categorical- categorical)

# %%
sns.clustermap(pd.crosstab(df['Parch'], df['Survived']))

# %%
sns.clustermap(pd.crosstab(df['SibSp'], df['Survived']))

# %% [markdown]
# 7.pairplot

# %%
df3 = pd.read_csv('iris.csv')
df3.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
sns.pairplot(df3, hue = 'species' )

# %%
sns.pairplot(df3, hue = 'sepal_length' )
