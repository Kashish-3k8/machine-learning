# %%
import numpy as np
import pickle

# %%
pipe = pickle.load(open('titanic_model.pkl', 'rb'))

# %%
#user input
user_input = np.array([[2,'male', 22.0,   1,    0,    7.25,   'S']])    # Example input: [Pclass, Age, SibSp, Parch, Fare, Embarked]

# %%
pipe.predict(user_input)
# Out:
# c:\Users\BIT\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# c:\Users\BIT\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)
